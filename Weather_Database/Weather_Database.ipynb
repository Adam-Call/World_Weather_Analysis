# %% [markdown]
# # DELIVERABLE 1

# %%
#Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
#import request library
import requests

#import API key
from config import weather_api_key

#Import datetime module
from datetime import datetime

# %%
# Create 2000 random longitude and latitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs= zip(lats,lngs)

# %%
#Add coordinates to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for cities.
cities = []

# Identify nearest city for lat_lngs combinations.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #Add to city list if unique city.
    if city not in cities:
        cities.append(city)
#print city count
len(cities)
# Out:
# 734

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create empty list to hold city weather data.
city_data = []

#Print statement initalizing the data retrieval.
print("     Begining Data Retrieval     ")
print('---------------------------------')

#Create counters for logging data retrieval.
record_count = 1
set_count = 1

#Loop through all cities in list retrieving data.
for i, city in enumerate(cities):
    #Group cities in cities for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count += 1
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    #Log URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # Add to record count
    record_count += 1
    
    #Run API request for each city.
    try:
        #parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #parse country, coordinates, max temp, humidity, cloudiness, wind speed, and weather description.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        #Convert date to ISO
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        #Append city information into list.
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Description': city_description,
                          'Date' : city_date})
    #If an error is experienced, skip city.
    except:
        print('City not found.Skipping...')
        pass
#Indicate that Data Loading is complete.
print('------------------------------')
print('Data Retrieval Complete       ')
print('------------------------------')
# Out:
#      Begining Data Retrieval
# ---------------------------------
# Processing Record 1 of Set 1 | airai
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | margate
# Processing Record 4 of Set 1 | grand river south east
# City not found.Skipping...
# Processing Record 5 of Set 1 | markivka
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found.Skipping...
# Processing Record 7 of Set 1 | carnarvon
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | sitka
# Processing Record 11 of Set 1 | sorong
# Processing Record 12 of Set 1 | soure
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | gangotri
# City not found.Skipping...
# Processing Record 16 of Set 1 | liwale
# Processing Record 17 of Set 1 | amderma
# City not found.Skipping...
# Processing Record 18 of Set 1 | louisbourg
# City not found.Skipping...
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | ternate
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | burica
# City not found.Skipping...
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | zhanakorgan
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | bur gabo
# City not found.Skipping...
# Processing Record 31 of Set 1 | laguna
# Processing Record 32 of Set 1 | champerico
# Processing Record 33 of Set 1 | buala
# Processing Record 34 of Set 1 | coahuayana
# Processing Record 35 of Set 1 | piacabucu
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | mayumba
# Processing Record 38 of Set 1 | butaritari
# Processing Record 39 of Set 1 | marystown
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | taolanaro
# City not found.Skipping...
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | cimarron hills
# Processing Record 48 of Set 1 | dwarka
# Processing Record 49 of Set 1 | fortuna
# Processing Record 50 of Set 1 | vaitupu
# City not found.Skipping...
# Processing Record 52 of Set 2 | georgetown
# Processing Record 53 of Set 2 | visby
# Processing Record 54 of Set 2 | kapaa
# Processing Record 55 of Set 2 | vardo
# Processing Record 56 of Set 2 | coihaique
# Processing Record 57 of Set 2 | baykit
# Processing Record 58 of Set 2 | esperance
# Processing Record 59 of Set 2 | sorvag
# City not found.Skipping...
# Processing Record 60 of Set 2 | aylesbury
# Processing Record 61 of Set 2 | portland
# Processing Record 62 of Set 2 | talakan
# Processing Record 63 of Set 2 | brigantine
# Processing Record 64 of Set 2 | kaitangata
# Processing Record 65 of Set 2 | ilulissat
# Processing Record 66 of Set 2 | bluff
# Processing Record 67 of Set 2 | longyearbyen
# Processing Record 68 of Set 2 | katsuura
# Processing Record 69 of Set 2 | chadiza
# Processing Record 70 of Set 2 | gat
# Processing Record 71 of Set 2 | ouadda
# Processing Record 72 of Set 2 | provideniya
# Processing Record 73 of Set 2 | tiksi
# Processing Record 74 of Set 2 | yurgamysh
# Processing Record 75 of Set 2 | hithadhoo
# Processing Record 76 of Set 2 | newberry
# Processing Record 77 of Set 2 | barrow
# Processing Record 78 of Set 2 | pishin
# Processing Record 79 of Set 2 | paamiut
# Processing Record 80 of Set 2 | goranboy
# Processing Record 81 of Set 2 | kodiak
# Processing Record 82 of Set 2 | izazi
# Processing Record 83 of Set 2 | puerto ayora
# Processing Record 84 of Set 2 | dikson
# Processing Record 85 of Set 2 | abatskoye
# Processing Record 86 of Set 2 | lagoa
# Processing Record 87 of Set 2 | namibe
# Processing Record 88 of Set 2 | kilindoni
# Processing Record 89 of Set 2 | cabedelo
# Processing Record 90 of Set 2 | lolua
# City not found.Skipping...
# Processing Record 91 of Set 2 | tshela
# Processing Record 92 of Set 2 | saldanha
# Processing Record 93 of Set 2 | la paz
# Processing Record 94 of Set 2 | sinnamary
# Processing Record 95 of Set 2 | irtyshskiy
# Processing Record 96 of Set 2 | terra santa
# Processing Record 97 of Set 2 | chokurdakh
# Processing Record 98 of Set 2 | svobodnyy
# Processing Record 99 of Set 2 | chara
# Processing Record 100 of Set 2 | castro
# Processing Record 101 of Set 2 | palana
# Processing Record 103 of Set 3 | durham
# Processing Record 104 of Set 3 | bama
# Processing Record 105 of Set 3 | nanortalik
# Processing Record 106 of Set 3 | cherskiy
# Processing Record 107 of Set 3 | umzimvubu
# City not found.Skipping...
# Processing Record 108 of Set 3 | faanui
# Processing Record 109 of Set 3 | vaini
# Processing Record 110 of Set 3 | norman wells
# Processing Record 111 of Set 3 | port alfred
# Processing Record 112 of Set 3 | avarua
# Processing Record 113 of Set 3 | belgrade
# Processing Record 114 of Set 3 | touros
# Processing Record 115 of Set 3 | san patricio
# Processing Record 116 of Set 3 | bouca
# Processing Record 117 of Set 3 | mys shmidta
# City not found.Skipping...
# Processing Record 118 of Set 3 | martapura
# Processing Record 119 of Set 3 | hobart
# Processing Record 120 of Set 3 | samarai
# Processing Record 121 of Set 3 | alexandria
# Processing Record 122 of Set 3 | poum
# Processing Record 123 of Set 3 | nizhneyansk
# City not found.Skipping...
# Processing Record 124 of Set 3 | pevek
# Processing Record 125 of Set 3 | kieta
# Processing Record 126 of Set 3 | volchanets
# Processing Record 127 of Set 3 | saint-philippe
# Processing Record 128 of Set 3 | geraldton
# Processing Record 129 of Set 3 | atuona
# Processing Record 130 of Set 3 | cagayan de tawi-tawi
# City not found.Skipping...
# Processing Record 131 of Set 3 | birjand
# Processing Record 132 of Set 3 | tasiilaq
# Processing Record 133 of Set 3 | atbasar
# Processing Record 134 of Set 3 | dabat
# Processing Record 135 of Set 3 | hermanus
# Processing Record 136 of Set 3 | clyde river
# Processing Record 137 of Set 3 | aksu
# Processing Record 138 of Set 3 | kjollefjord
# Processing Record 139 of Set 3 | yerbogachen
# Processing Record 140 of Set 3 | kutum
# Processing Record 141 of Set 3 | grindavik
# Processing Record 142 of Set 3 | cape town
# Processing Record 143 of Set 3 | nuevo progreso
# Processing Record 144 of Set 3 | cidreira
# Processing Record 145 of Set 3 | riberalta
# Processing Record 146 of Set 3 | bay roberts
# Processing Record 147 of Set 3 | qandala
# Processing Record 148 of Set 3 | verkhnevilyuysk
# Processing Record 149 of Set 3 | avera
# Processing Record 150 of Set 3 | barentsburg
# City not found.Skipping...
# Processing Record 151 of Set 3 | joinville
# Processing Record 152 of Set 3 | blyth
# Processing Record 154 of Set 4 | alpena
# Processing Record 155 of Set 4 | aginskoye
# Processing Record 156 of Set 4 | endicott
# Processing Record 157 of Set 4 | haines junction
# Processing Record 158 of Set 4 | samana
# Processing Record 159 of Set 4 | almargem do bispo
# Processing Record 160 of Set 4 | russell
# Processing Record 161 of Set 4 | tagab
# Processing Record 162 of Set 4 | trelew
# Processing Record 163 of Set 4 | caconda
# Processing Record 164 of Set 4 | inta
# Processing Record 165 of Set 4 | christchurch
# Processing Record 166 of Set 4 | san cristobal
# Processing Record 167 of Set 4 | saskylakh
# Processing Record 168 of Set 4 | enshi
# Processing Record 169 of Set 4 | asau
# Processing Record 170 of Set 4 | luderitz
# Processing Record 171 of Set 4 | salmas
# Processing Record 172 of Set 4 | port hardy
# Processing Record 173 of Set 4 | ahipara
# Processing Record 174 of Set 4 | port elizabeth
# Processing Record 175 of Set 4 | necochea
# Processing Record 176 of Set 4 | rawson
# Processing Record 177 of Set 4 | derzhavinsk
# Processing Record 178 of Set 4 | yar-sale
# Processing Record 179 of Set 4 | pisco
# Processing Record 180 of Set 4 | santa vitoria
# Processing Record 181 of Set 4 | olafsvik
# Processing Record 182 of Set 4 | charters towers
# Processing Record 183 of Set 4 | bengkulu
# Processing Record 184 of Set 4 | mabaruma
# Processing Record 185 of Set 4 | okhotsk
# Processing Record 186 of Set 4 | ust-kulom
# Processing Record 187 of Set 4 | murgab
# Processing Record 188 of Set 4 | constitucion
# Processing Record 189 of Set 4 | port hedland
# Processing Record 190 of Set 4 | hofn
# Processing Record 191 of Set 4 | zouxian
# City not found.Skipping...
# Processing Record 192 of Set 4 | pemangkat
# Processing Record 193 of Set 4 | korba
# Processing Record 194 of Set 4 | belushya guba
# City not found.Skipping...
# Processing Record 195 of Set 4 | khatanga
# Processing Record 196 of Set 4 | qaanaaq
# Processing Record 197 of Set 4 | thompson
# Processing Record 198 of Set 4 | kegayli
# City not found.Skipping...
# Processing Record 199 of Set 4 | panama city
# Processing Record 200 of Set 4 | hilo
# Processing Record 201 of Set 4 | saleaula
# City not found.Skipping...
# Processing Record 202 of Set 4 | palabuhanratu
# City not found.Skipping...
# Processing Record 203 of Set 4 | vao
# Processing Record 205 of Set 5 | sao filipe
# Processing Record 206 of Set 5 | lompoc
# Processing Record 207 of Set 5 | vyborg
# Processing Record 208 of Set 5 | ambilobe
# Processing Record 209 of Set 5 | rabo de peixe
# Processing Record 210 of Set 5 | odweyne
# Processing Record 211 of Set 5 | santa cruz
# Processing Record 212 of Set 5 | la ronge
# Processing Record 213 of Set 5 | valparaiso
# Processing Record 214 of Set 5 | hamilton
# Processing Record 215 of Set 5 | claveria
# Processing Record 216 of Set 5 | saint-denis
# Processing Record 217 of Set 5 | vredendal
# Processing Record 218 of Set 5 | victoria
# Processing Record 219 of Set 5 | tomatlan
# Processing Record 220 of Set 5 | kavaratti
# Processing Record 221 of Set 5 | eyl
# Processing Record 222 of Set 5 | saint-leu
# Processing Record 223 of Set 5 | san pedro
# Processing Record 224 of Set 5 | kuryk
# Processing Record 225 of Set 5 | tautira
# Processing Record 226 of Set 5 | fuerte olimpo
# Processing Record 227 of Set 5 | sehithwa
# Processing Record 228 of Set 5 | pahrump
# Processing Record 229 of Set 5 | nyurba
# Processing Record 230 of Set 5 | leningradskiy
# Processing Record 231 of Set 5 | nishihara
# Processing Record 232 of Set 5 | kavieng
# Processing Record 233 of Set 5 | kindersley
# Processing Record 234 of Set 5 | pringsewu
# Processing Record 235 of Set 5 | saint-francois
# Processing Record 236 of Set 5 | severo-kurilsk
# Processing Record 237 of Set 5 | nelson bay
# Processing Record 238 of Set 5 | progreso
# Processing Record 239 of Set 5 | evensk
# Processing Record 240 of Set 5 | olivenza
# Processing Record 241 of Set 5 | malwan
# City not found.Skipping...
# Processing Record 242 of Set 5 | attawapiskat
# City not found.Skipping...
# Processing Record 243 of Set 5 | auki
# Processing Record 244 of Set 5 | aklavik
# Processing Record 245 of Set 5 | narasannapeta
# Processing Record 246 of Set 5 | honiara
# Processing Record 247 of Set 5 | mitsamiouli
# Processing Record 248 of Set 5 | sechura
# Processing Record 249 of Set 5 | cristalina
# Processing Record 250 of Set 5 | bartica
# Processing Record 251 of Set 5 | oranjemund
# Processing Record 252 of Set 5 | hami
# Processing Record 253 of Set 5 | umba
# Processing Record 254 of Set 5 | beringovskiy
# Processing Record 256 of Set 6 | satitoa
# City not found.Skipping...
# Processing Record 257 of Set 6 | narrabri
# Processing Record 258 of Set 6 | kryzhanivka
# Processing Record 259 of Set 6 | xai-xai
# Processing Record 260 of Set 6 | souillac
# Processing Record 261 of Set 6 | bouna
# Processing Record 262 of Set 6 | ogawa
# Processing Record 263 of Set 6 | ngukurr
# City not found.Skipping...
# Processing Record 264 of Set 6 | lebu
# Processing Record 265 of Set 6 | agirish
# Processing Record 266 of Set 6 | porto santo
# Processing Record 267 of Set 6 | urdzhar
# City not found.Skipping...
# Processing Record 268 of Set 6 | carutapera
# Processing Record 269 of Set 6 | sentyabrskiy
# City not found.Skipping...
# Processing Record 270 of Set 6 | itororo
# Processing Record 271 of Set 6 | wajima
# Processing Record 272 of Set 6 | buribay
# Processing Record 273 of Set 6 | lapua
# Processing Record 274 of Set 6 | pauini
# Processing Record 275 of Set 6 | vila franca do campo
# Processing Record 276 of Set 6 | henties bay
# Processing Record 277 of Set 6 | harper
# Processing Record 278 of Set 6 | marienburg
# Processing Record 279 of Set 6 | kibala
# Processing Record 280 of Set 6 | bambous virieux
# Processing Record 281 of Set 6 | kruisfontein
# Processing Record 282 of Set 6 | camanci
# City not found.Skipping...
# Processing Record 283 of Set 6 | chapais
# Processing Record 284 of Set 6 | cayenne
# Processing Record 285 of Set 6 | narsaq
# Processing Record 286 of Set 6 | yaan
# Processing Record 287 of Set 6 | muisne
# Processing Record 288 of Set 6 | pacific grove
# Processing Record 289 of Set 6 | caluquembe
# Processing Record 290 of Set 6 | aloleng
# Processing Record 291 of Set 6 | jumla
# Processing Record 292 of Set 6 | asyut
# Processing Record 293 of Set 6 | mairang
# Processing Record 294 of Set 6 | guerrero negro
# Processing Record 295 of Set 6 | ortona
# Processing Record 296 of Set 6 | alofi
# Processing Record 297 of Set 6 | makueni
# Processing Record 298 of Set 6 | kitui
# Processing Record 299 of Set 6 | gravdal
# Processing Record 300 of Set 6 | jiayuguan
# Processing Record 301 of Set 6 | saint-augustin
# Processing Record 302 of Set 6 | tome
# Processing Record 303 of Set 6 | kundiawa
# Processing Record 304 of Set 6 | pokaran
# Processing Record 305 of Set 6 | praia da vitoria
# Processing Record 307 of Set 7 | halalo
# City not found.Skipping...
# Processing Record 308 of Set 7 | atlantic city
# Processing Record 309 of Set 7 | otofuke
# Processing Record 310 of Set 7 | te anau
# Processing Record 311 of Set 7 | gilgit
# Processing Record 312 of Set 7 | kadykchan
# City not found.Skipping...
# Processing Record 313 of Set 7 | newport beach
# Processing Record 314 of Set 7 | shu
# Processing Record 315 of Set 7 | ketchikan
# Processing Record 316 of Set 7 | boone
# Processing Record 317 of Set 7 | puerto baquerizo moreno
# Processing Record 318 of Set 7 | woodward
# Processing Record 319 of Set 7 | fairbanks
# Processing Record 320 of Set 7 | upernavik
# Processing Record 321 of Set 7 | belousovka
# Processing Record 322 of Set 7 | magadan
# Processing Record 323 of Set 7 | bembereke
# Processing Record 324 of Set 7 | tabiauea
# City not found.Skipping...
# Processing Record 325 of Set 7 | tuatapere
# Processing Record 326 of Set 7 | uaua
# Processing Record 327 of Set 7 | lakinsk
# Processing Record 328 of Set 7 | janakkala
# Processing Record 329 of Set 7 | port lincoln
# Processing Record 330 of Set 7 | xirokambos
# City not found.Skipping...
# Processing Record 331 of Set 7 | kiunga
# Processing Record 332 of Set 7 | sibolga
# Processing Record 333 of Set 7 | nuuk
# Processing Record 334 of Set 7 | lukow
# Processing Record 335 of Set 7 | hasaki
# Processing Record 336 of Set 7 | monte plata
# Processing Record 337 of Set 7 | marsh harbour
# Processing Record 338 of Set 7 | quatre cocos
# Processing Record 339 of Set 7 | umea
# Processing Record 340 of Set 7 | tsihombe
# City not found.Skipping...
# Processing Record 341 of Set 7 | kirakira
# Processing Record 342 of Set 7 | coquimbo
# Processing Record 343 of Set 7 | meulaboh
# Processing Record 344 of Set 7 | dingle
# Processing Record 345 of Set 7 | nantucket
# Processing Record 346 of Set 7 | zhigansk
# Processing Record 347 of Set 7 | pedregulho
# Processing Record 348 of Set 7 | shelburne
# Processing Record 349 of Set 7 | drochia
# Processing Record 350 of Set 7 | kismayo
# Processing Record 351 of Set 7 | kiama
# Processing Record 352 of Set 7 | cabo san lucas
# Processing Record 353 of Set 7 | popondetta
# Processing Record 354 of Set 7 | kamenka
# Processing Record 355 of Set 7 | svetlogorsk
# Processing Record 356 of Set 7 | waingapu
# Processing Record 358 of Set 8 | port blair
# Processing Record 359 of Set 8 | karratha
# Processing Record 360 of Set 8 | rohnert park
# Processing Record 361 of Set 8 | camaqua
# Processing Record 362 of Set 8 | saurimo
# Processing Record 363 of Set 8 | viedma
# Processing Record 364 of Set 8 | nanchang
# Processing Record 365 of Set 8 | chardara
# Processing Record 366 of Set 8 | maromitsa
# Processing Record 367 of Set 8 | turukhansk
# Processing Record 368 of Set 8 | mangrol
# Processing Record 369 of Set 8 | bendigo
# Processing Record 370 of Set 8 | breves
# Processing Record 371 of Set 8 | marcona
# City not found.Skipping...
# Processing Record 372 of Set 8 | banda aceh
# Processing Record 373 of Set 8 | socorro
# Processing Record 374 of Set 8 | los llanos de aridane
# Processing Record 375 of Set 8 | ixtapa
# Processing Record 376 of Set 8 | tacuarembo
# Processing Record 377 of Set 8 | mar del plata
# Processing Record 378 of Set 8 | tupiza
# Processing Record 379 of Set 8 | muros
# Processing Record 380 of Set 8 | taunggyi
# Processing Record 381 of Set 8 | tangjiazhuang
# Processing Record 382 of Set 8 | umm kaddadah
# Processing Record 383 of Set 8 | maghama
# City not found.Skipping...
# Processing Record 384 of Set 8 | grindsted
# Processing Record 385 of Set 8 | iqaluit
# Processing Record 386 of Set 8 | casablanca
# Processing Record 387 of Set 8 | manaus
# Processing Record 388 of Set 8 | ancud
# Processing Record 389 of Set 8 | charyshskoye
# Processing Record 390 of Set 8 | boende
# Processing Record 391 of Set 8 | zyryanka
# Processing Record 392 of Set 8 | merritt
# Processing Record 393 of Set 8 | benghazi
# Processing Record 394 of Set 8 | ostrovnoy
# Processing Record 395 of Set 8 | byron bay
# Processing Record 396 of Set 8 | tunghsiao
# City not found.Skipping...
# Processing Record 397 of Set 8 | presidencia roque saenz pena
# Processing Record 398 of Set 8 | taganak
# Processing Record 399 of Set 8 | faya
# Processing Record 400 of Set 8 | east london
# Processing Record 401 of Set 8 | maniitsoq
# Processing Record 402 of Set 8 | lircay
# Processing Record 403 of Set 8 | imbituba
# Processing Record 404 of Set 8 | kijang
# Processing Record 405 of Set 8 | islamkot
# Processing Record 406 of Set 8 | kloulklubed
# Processing Record 407 of Set 8 | careiro da varzea
# Processing Record 409 of Set 9 | rocha
# Processing Record 410 of Set 9 | sanger
# Processing Record 411 of Set 9 | yialos
# City not found.Skipping...
# Processing Record 412 of Set 9 | hay river
# Processing Record 413 of Set 9 | bud
# Processing Record 414 of Set 9 | okha
# Processing Record 415 of Set 9 | saint george
# Processing Record 416 of Set 9 | roma
# Processing Record 417 of Set 9 | itaqui
# Processing Record 418 of Set 9 | palmerston north
# Processing Record 419 of Set 9 | el burrion
# Processing Record 420 of Set 9 | muyezerskiy
# Processing Record 421 of Set 9 | general roca
# Processing Record 422 of Set 9 | pecos
# Processing Record 423 of Set 9 | xingyi
# Processing Record 424 of Set 9 | podporozhye
# Processing Record 425 of Set 9 | barranca
# Processing Record 426 of Set 9 | batagay-alyta
# Processing Record 427 of Set 9 | lavrentiya
# Processing Record 428 of Set 9 | kyle of lochalsh
# City not found.Skipping...
# Processing Record 429 of Set 9 | mandera
# Processing Record 430 of Set 9 | flinders
# Processing Record 431 of Set 9 | atagay
# Processing Record 432 of Set 9 | dinsor
# City not found.Skipping...
# Processing Record 433 of Set 9 | puquio
# Processing Record 434 of Set 9 | beloha
# Processing Record 435 of Set 9 | datong
# Processing Record 436 of Set 9 | kabo
# Processing Record 437 of Set 9 | kudahuvadhoo
# Processing Record 438 of Set 9 | tatawin
# Processing Record 439 of Set 9 | lagunas
# Processing Record 440 of Set 9 | asekeyevo
# Processing Record 441 of Set 9 | kailua
# Processing Record 442 of Set 9 | berlevag
# Processing Record 443 of Set 9 | mandalay
# Processing Record 444 of Set 9 | smolenskoye
# Processing Record 445 of Set 9 | chicama
# Processing Record 446 of Set 9 | kalemie
# Processing Record 447 of Set 9 | amapa
# Processing Record 448 of Set 9 | antropovo
# Processing Record 449 of Set 9 | nome
# Processing Record 450 of Set 9 | goderich
# Processing Record 451 of Set 9 | xiaoshi
# Processing Record 452 of Set 9 | glenwood springs
# Processing Record 453 of Set 9 | mahajanga
# Processing Record 454 of Set 9 | abu dhabi
# Processing Record 455 of Set 9 | amahai
# Processing Record 456 of Set 9 | korla
# Processing Record 457 of Set 9 | norrtalje
# Processing Record 458 of Set 9 | inuvik
# Processing Record 460 of Set 10 | geresk
# City not found.Skipping...
# Processing Record 461 of Set 10 | naze
# Processing Record 462 of Set 10 | anchorage
# Processing Record 463 of Set 10 | riyadh
# Processing Record 464 of Set 10 | rio branco
# Processing Record 465 of Set 10 | sume
# Processing Record 466 of Set 10 | mackenzie
# Processing Record 467 of Set 10 | paris
# Processing Record 468 of Set 10 | palmer
# Processing Record 469 of Set 10 | bolungarvik
# City not found.Skipping...
# Processing Record 470 of Set 10 | chagda
# City not found.Skipping...
# Processing Record 471 of Set 10 | altay
# Processing Record 472 of Set 10 | jardim
# Processing Record 473 of Set 10 | codrington
# Processing Record 474 of Set 10 | biak
# Processing Record 475 of Set 10 | guatire
# Processing Record 476 of Set 10 | winneba
# Processing Record 477 of Set 10 | lermontovka
# Processing Record 478 of Set 10 | sambava
# Processing Record 479 of Set 10 | namatanai
# Processing Record 480 of Set 10 | havre-saint-pierre
# Processing Record 481 of Set 10 | alpinopolis
# Processing Record 482 of Set 10 | swiecie
# Processing Record 483 of Set 10 | marawi
# Processing Record 484 of Set 10 | augustow
# Processing Record 485 of Set 10 | pampa
# Processing Record 486 of Set 10 | san rafael
# Processing Record 487 of Set 10 | puerto escondido
# Processing Record 488 of Set 10 | paragominas
# Processing Record 489 of Set 10 | isangel
# Processing Record 490 of Set 10 | bintulu
# Processing Record 491 of Set 10 | fonte boa
# Processing Record 492 of Set 10 | port-cartier
# Processing Record 493 of Set 10 | aykhal
# Processing Record 494 of Set 10 | tubruq
# City not found.Skipping...
# Processing Record 495 of Set 10 | roald
# Processing Record 496 of Set 10 | muzhi
# Processing Record 497 of Set 10 | malyye derbety
# Processing Record 498 of Set 10 | quetzaltepec
# City not found.Skipping...
# Processing Record 499 of Set 10 | mount gambier
# Processing Record 500 of Set 10 | ust-uda
# Processing Record 501 of Set 10 | gavrilovka vtoraya
# Processing Record 502 of Set 10 | bathsheba
# Processing Record 503 of Set 10 | pljevlja
# Processing Record 504 of Set 10 | yabelo
# Processing Record 505 of Set 10 | aalestrup
# City not found.Skipping...
# Processing Record 506 of Set 10 | macherla
# Processing Record 507 of Set 10 | palatka
# Processing Record 508 of Set 10 | lodja
# Processing Record 509 of Set 10 | storforshei
# Processing Record 511 of Set 11 | havre
# Processing Record 512 of Set 11 | worthington
# Processing Record 513 of Set 11 | whitehorse
# Processing Record 514 of Set 11 | miraflores
# Processing Record 515 of Set 11 | makakilo city
# Processing Record 516 of Set 11 | saquarema
# Processing Record 517 of Set 11 | bacuit
# City not found.Skipping...
# Processing Record 518 of Set 11 | ornskoldsvik
# Processing Record 519 of Set 11 | the pas
# Processing Record 520 of Set 11 | churapcha
# Processing Record 521 of Set 11 | talnakh
# Processing Record 522 of Set 11 | dicabisagan
# Processing Record 523 of Set 11 | dabeiba
# Processing Record 524 of Set 11 | praia
# Processing Record 525 of Set 11 | solnechnyy
# Processing Record 526 of Set 11 | warqla
# City not found.Skipping...
# Processing Record 527 of Set 11 | ampanihy
# Processing Record 528 of Set 11 | gagarin
# Processing Record 529 of Set 11 | buckingham
# Processing Record 530 of Set 11 | bilibino
# Processing Record 531 of Set 11 | juneau
# Processing Record 532 of Set 11 | seoul
# Processing Record 533 of Set 11 | mount hagen
# Processing Record 534 of Set 11 | tay ninh
# Processing Record 535 of Set 11 | mpika
# Processing Record 536 of Set 11 | tura
# Processing Record 537 of Set 11 | barroualie
# City not found.Skipping...
# Processing Record 538 of Set 11 | maceio
# Processing Record 539 of Set 11 | alta floresta
# Processing Record 540 of Set 11 | caridad
# Processing Record 541 of Set 11 | chesley
# Processing Record 542 of Set 11 | broome
# Processing Record 543 of Set 11 | bongor
# Processing Record 544 of Set 11 | north platte
# Processing Record 545 of Set 11 | anadyr
# Processing Record 546 of Set 11 | bilma
# Processing Record 547 of Set 11 | brae
# Processing Record 548 of Set 11 | le port
# Processing Record 549 of Set 11 | saint anthony
# Processing Record 550 of Set 11 | abu samrah
# Processing Record 551 of Set 11 | alice springs
# Processing Record 552 of Set 11 | port-gentil
# Processing Record 553 of Set 11 | grand gaube
# Processing Record 554 of Set 11 | kaeo
# Processing Record 555 of Set 11 | merauke
# Processing Record 556 of Set 11 | kita
# Processing Record 557 of Set 11 | kentau
# Processing Record 558 of Set 11 | kaspiysk
# Processing Record 559 of Set 11 | samusu
# City not found.Skipping...
# Processing Record 560 of Set 11 | haibowan
# City not found.Skipping...
# Processing Record 562 of Set 12 | yuzawa
# Processing Record 563 of Set 12 | sorland
# Processing Record 564 of Set 12 | fort nelson
# Processing Record 565 of Set 12 | el rusio
# Processing Record 566 of Set 12 | kopervik
# Processing Record 567 of Set 12 | khormuj
# City not found.Skipping...
# Processing Record 568 of Set 12 | chirongui
# Processing Record 569 of Set 12 | jeremie
# Processing Record 570 of Set 12 | meyungs
# City not found.Skipping...
# Processing Record 571 of Set 12 | salalah
# Processing Record 572 of Set 12 | scottsburgh
# City not found.Skipping...
# Processing Record 573 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 574 of Set 12 | saint-georges
# Processing Record 575 of Set 12 | upata
# Processing Record 576 of Set 12 | pitimbu
# Processing Record 577 of Set 12 | maldonado
# Processing Record 578 of Set 12 | tessalit
# Processing Record 579 of Set 12 | santa maria
# Processing Record 580 of Set 12 | dolbeau
# City not found.Skipping...
# Processing Record 581 of Set 12 | tupelo
# Processing Record 582 of Set 12 | manoel urbano
# Processing Record 583 of Set 12 | rieti
# Processing Record 584 of Set 12 | monrovia
# Processing Record 585 of Set 12 | pedernales
# Processing Record 586 of Set 12 | imeni karla libknekhta
# Processing Record 587 of Set 12 | surdulica
# Processing Record 588 of Set 12 | hurghada
# Processing Record 589 of Set 12 | kapoeta
# Processing Record 590 of Set 12 | camana
# Processing Record 591 of Set 12 | novyy urengoy
# Processing Record 592 of Set 12 | kokopo
# Processing Record 593 of Set 12 | usinsk
# Processing Record 594 of Set 12 | armizonskoye
# Processing Record 595 of Set 12 | gloversville
# Processing Record 596 of Set 12 | tumannyy
# City not found.Skipping...
# Processing Record 597 of Set 12 | inhambane
# Processing Record 598 of Set 12 | dharan
# Processing Record 599 of Set 12 | vostok
# Processing Record 600 of Set 12 | lusambo
# Processing Record 601 of Set 12 | duz
# City not found.Skipping...
# Processing Record 602 of Set 12 | pachmarhi
# Processing Record 603 of Set 12 | huai yot
# Processing Record 604 of Set 12 | acurenam
# Processing Record 605 of Set 12 | izmit
# Processing Record 606 of Set 12 | ponta delgada
# Processing Record 607 of Set 12 | novopokrovka
# Processing Record 608 of Set 12 | qeshm
# Processing Record 609 of Set 12 | makat
# Processing Record 610 of Set 12 | itarema
# Processing Record 611 of Set 12 | vila velha
# Processing Record 613 of Set 13 | port macquarie
# Processing Record 614 of Set 13 | zlatoust
# Processing Record 615 of Set 13 | dudinka
# Processing Record 616 of Set 13 | hualmay
# Processing Record 617 of Set 13 | ocos
# Processing Record 618 of Set 13 | labelle
# Processing Record 619 of Set 13 | sao joao da barra
# Processing Record 620 of Set 13 | westport
# Processing Record 621 of Set 13 | kurilsk
# Processing Record 622 of Set 13 | luena
# Processing Record 623 of Set 13 | kendari
# Processing Record 624 of Set 13 | tahoua
# Processing Record 625 of Set 13 | hastings
# Processing Record 626 of Set 13 | mattawa
# Processing Record 627 of Set 13 | ngaoundere
# Processing Record 628 of Set 13 | hambantota
# Processing Record 629 of Set 13 | cerritos
# Processing Record 630 of Set 13 | lorengau
# Processing Record 631 of Set 13 | wamba
# Processing Record 632 of Set 13 | seminole
# Processing Record 633 of Set 13 | suntar
# Processing Record 634 of Set 13 | davila
# Processing Record 635 of Set 13 | ulaanbaatar
# Processing Record 636 of Set 13 | chkalovsk
# Processing Record 637 of Set 13 | catarman
# Processing Record 638 of Set 13 | san quintin
# Processing Record 639 of Set 13 | sinfra
# Processing Record 640 of Set 13 | conceicao do araguaia
# Processing Record 641 of Set 13 | san benito
# Processing Record 642 of Set 13 | salym
# Processing Record 643 of Set 13 | shrewsbury
# Processing Record 644 of Set 13 | husavik
# Processing Record 645 of Set 13 | yilan
# Processing Record 646 of Set 13 | nova granada
# Processing Record 647 of Set 13 | issa
# Processing Record 648 of Set 13 | katherine
# Processing Record 649 of Set 13 | makokou
# Processing Record 650 of Set 13 | tabriz
# Processing Record 651 of Set 13 | porbandar
# Processing Record 652 of Set 13 | chissamba
# Processing Record 653 of Set 13 | galiwinku
# City not found.Skipping...
# Processing Record 654 of Set 13 | novodugino
# Processing Record 655 of Set 13 | santa fe
# Processing Record 656 of Set 13 | malinovoye ozero
# Processing Record 657 of Set 13 | bonavista
# Processing Record 658 of Set 13 | sataua
# City not found.Skipping...
# Processing Record 659 of Set 13 | rio grande
# Processing Record 660 of Set 13 | domna
# Processing Record 661 of Set 13 | bairiki
# Processing Record 662 of Set 13 | maragogi
# Processing Record 664 of Set 14 | mogadishu
# Processing Record 665 of Set 14 | villanueva de cordoba
# Processing Record 666 of Set 14 | maykain
# City not found.Skipping...
# Processing Record 667 of Set 14 | kununurra
# Processing Record 668 of Set 14 | natal
# Processing Record 669 of Set 14 | camacupa
# Processing Record 670 of Set 14 | ijaki
# City not found.Skipping...
# Processing Record 671 of Set 14 | tukrah
# Processing Record 672 of Set 14 | arona
# Processing Record 673 of Set 14 | itiuba
# Processing Record 674 of Set 14 | viligili
# City not found.Skipping...
# Processing Record 675 of Set 14 | najran
# Processing Record 676 of Set 14 | taldan
# Processing Record 677 of Set 14 | isla vista
# Processing Record 678 of Set 14 | bronnoysund
# Processing Record 679 of Set 14 | bukid
# Processing Record 680 of Set 14 | karauzyak
# City not found.Skipping...
# Processing Record 681 of Set 14 | severnyy
# Processing Record 682 of Set 14 | lasa
# Processing Record 683 of Set 14 | murupara
# Processing Record 684 of Set 14 | kirkland lake
# Processing Record 685 of Set 14 | woodstock
# Processing Record 686 of Set 14 | doiwala
# Processing Record 687 of Set 14 | gubkinskiy
# Processing Record 688 of Set 14 | letterkenny
# Processing Record 689 of Set 14 | selenginsk
# Processing Record 690 of Set 14 | zabid
# Processing Record 691 of Set 14 | mount isa
# Processing Record 692 of Set 14 | mareeba
# Processing Record 693 of Set 14 | mehamn
# Processing Record 694 of Set 14 | versalles
# Processing Record 695 of Set 14 | mandawar
# Processing Record 696 of Set 14 | clive
# Processing Record 697 of Set 14 | tucuman
# Processing Record 698 of Set 14 | khasan
# Processing Record 699 of Set 14 | el dorado
# Processing Record 700 of Set 14 | caranavi
# Processing Record 701 of Set 14 | matara
# Processing Record 702 of Set 14 | cockburn town
# Processing Record 703 of Set 14 | tiznit
# Processing Record 704 of Set 14 | sarahan
# Processing Record 705 of Set 14 | formoso do araguaia
# City not found.Skipping...
# Processing Record 706 of Set 14 | balsas
# Processing Record 707 of Set 14 | hoi an
# Processing Record 708 of Set 14 | luanda
# Processing Record 709 of Set 14 | uruzgan
# Processing Record 710 of Set 14 | porto velho
# Processing Record 711 of Set 14 | la libertad
# Processing Record 712 of Set 14 | bahia honda
# Processing Record 713 of Set 14 | east palo alto
# Processing Record 715 of Set 15 | buraydah
# Processing Record 716 of Set 15 | half moon bay
# Processing Record 717 of Set 15 | sisimiut
# Processing Record 718 of Set 15 | sinaloa
# Processing Record 719 of Set 15 | tazovskiy
# Processing Record 720 of Set 15 | valentin gomez farias
# Processing Record 721 of Set 15 | ustye
# Processing Record 722 of Set 15 | benton harbor
# Processing Record 723 of Set 15 | miandrivazo
# Processing Record 724 of Set 15 | terney
# Processing Record 725 of Set 15 | nara
# Processing Record 726 of Set 15 | lai
# Processing Record 727 of Set 15 | taoudenni
# Processing Record 728 of Set 15 | idah
# Processing Record 729 of Set 15 | cabiraoan
# Processing Record 730 of Set 15 | lata
# Processing Record 731 of Set 15 | spartanburg
# Processing Record 732 of Set 15 | ipixuna
# Processing Record 733 of Set 15 | erdemli
# Processing Record 734 of Set 15 | changde
# Processing Record 735 of Set 15 | halifax
# Processing Record 736 of Set 15 | voi
# Processing Record 737 of Set 15 | san jeronimo
# Processing Record 738 of Set 15 | shubarkuduk
# Processing Record 739 of Set 15 | mogzon
# Processing Record 740 of Set 15 | labuhan
# Processing Record 741 of Set 15 | pasighat
# Processing Record 742 of Set 15 | daru
# Processing Record 743 of Set 15 | arlit
# Processing Record 744 of Set 15 | qaqortoq
# Processing Record 745 of Set 15 | zhelyabovka
# Processing Record 746 of Set 15 | kirksville
# Processing Record 747 of Set 15 | fethiye
# Processing Record 748 of Set 15 | maihar
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %%
# Convert array to a  Dataframe.
city_data_df = pd.DataFrame(city_data)

# Reorder dataframe.
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Airai      TL  -8.9266  125.4092     72.88        55          28
# 1  Bredasdorp      ZA -34.5322   20.0403     44.60        87           1
# 2     Margate      GB  51.3813    1.3862     42.01        78           3
# 3    Markivka      UA  49.5229   39.5705     50.59        67          75
# 4   Carnarvon      AU -24.8667  113.6333     84.76        39           2
#
#    Wind Speed       Description
# 0        4.88  scattered clouds
# 1        5.75         clear sky
# 2        4.00         clear sky
# 3       10.09        light rain
# 4        8.10         clear sky

# %%
#Check for null values.
city_data_df.isnull().count()
# Out:
# City           671
# Country        671
# Lat            671
# Lng            671
# Max Temp       671
# Humidity       671
# Cloudiness     671
# Wind Speed     671
# Description    671
# dtype: int64

# %%
#Create output file (CSV)
output_data_file = 'Weather_Database/WeatherPy_Database.csv'
#Export CIty_Data into CSV.
city_data_df.to_csv(output_data_file, index_label='City_ID')
